# %% [markdown]
# # Lecture 9 R Demo
#
# ## History of Data Science, Spring 2022

# %%
data()

# %%
data(mtcars)

# %%
head(mtcars, 10)

# %%
x <- mtcars$wt
x

# %%
y <- mtcars$mpg
y

# %%
plot(x, y, pch=19)

# %%
plot(x, y, 
     main = "Main title",
     xlab = "X axis title", 
     ylab = "Y axis title",
     pch = 19, 
     frame = FALSE)
abline(lm(y ~ x), col='blue')
